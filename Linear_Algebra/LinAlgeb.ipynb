# %% [markdown]
# # Linear Algebra

# %%
import numpy as np

# %% [markdown]
# <H1> Vector Operations </H1>

# %%
u = np.array([2,4,5,6])

# %%
u
# Out:
# array([2, 4, 5, 6])

# %%
v = np.array([1,0,0,2])

# %%
v
# Out:
# array([1, 0, 0, 2])

# %%
u + v
# Out:
# array([3, 4, 5, 8])

# %%
u * v
# Out:
# array([ 2,  0,  0, 12])

# %% [markdown]
# <H1> Multiplication </H1>

# %%
u.shape
# Out:
# (4,)

# %%
v.shape
# Out:
# (4,)

# %%
def vector_vector_multiplication(u,v):
    assert u.shape[0]==v.shape[0] #vector should be of same size
    n =u.shape[0]
    result = 0.0
    for i in range(n):
        result = result + u[i] * v[i]
    return result

# %%
vector_vector_multiplication(u,v)
# Out:
# np.float64(14.0)

# %%
u.dot(v)
# Out:
# np.int64(14)

# %%
def matrix_vector_multiplication(U,v):
    assert U.shape[1]==v.shape[0]
    num_rows = U.shape[0]
    result = np.zeros(num_rows)
    for i in range(num_rows):
        result[i] = vector_vector_multiplication(U[i],v)
    return result

# %%
U = np.array([[2,4,5,6],
              [1,2,1,2],
              [3,1,2,1],
             ])

# %%
matrix_vector_multiplication(U,v)
# Out:
# array([14.,  5.,  5.])

# %%
U.dot(v)
# Out:
# array([14,  5,  5])

# %%
V = np.array([[1,1,2],
              [0,0.5,1],
              [0,2,1],
              [2,1,0],
             ])

# %%
def matrix_matrix_multiplication(U,V):
    assert U.shape[1]==V.shape[0]
    num_rows = U.shape[0]
    num_cols = V.shape[1]
    result = np.zeros([num_rows , num_cols])
    for i in range(num_cols):
        vi = V[:,i]
        Uvi = matrix_vector_multiplication(U,vi)
        result[ : ,i] = Uvi
    return result

# %%
matrix_matrix_multiplication(U,V)
# Out:
# array([[14. , 20. , 13. ],
#        [ 5. ,  6. ,  5. ],
#        [ 5. ,  8.5,  9. ]])

# %%
U.dot(V)
# Out:
# array([[14. , 20. , 13. ],
#        [ 5. ,  6. ,  5. ],
#        [ 5. ,  8.5,  9. ]])

# %% [markdown]
# <H1> Identity Matrix </H1>

# %%
I = np.eye(3)
I
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
V
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %%
V.dot(I)
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %% [markdown]
# <H1> Inverse </H1>

# %%
Vs = V[[0,1,2]] # Square matrix
Vs
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ]])

# %%
Vs_inverse = np.linalg.inv(Vs)
Vs_inverse
# Out:
# array([[ 1.        , -2.        ,  0.        ],
#        [ 0.        , -0.66666667,  0.66666667],
#        [ 0.        ,  1.33333333, -0.33333333]])

# %% [markdown]
# $AA^{-1}=I$

# %%
Vs_inverse.dot(Vs)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
