# %% [markdown]
# # Linear Algebra

# %%
import numpy as np

# %% [markdown]
# <H1> Vector Operations </H1>

# %%
u = np.array([2,4,5,6])

# %%
u
# Out:
# array([2, 4, 5, 6])

# %%
v = np.array([1,0,0,2])

# %%
v
# Out:
# array([1, 0, 0, 2])

# %%
u + v
# Out:
# array([3, 4, 5, 8])

# %%
u * v
# Out:
# array([ 2,  0,  0, 12])

# %% [markdown]
# <H1> Multiplication </H1>
